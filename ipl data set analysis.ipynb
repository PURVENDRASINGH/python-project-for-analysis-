# %%
import  pandas  as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\puru\Desktop

# %%
df = pd.read_csv("ipl.csv")
df
# Out:
#       id  season       city       date                        team1  \
# 0      1    2017  Hyderabad   4/5/2017          Sunrisers Hyderabad
# 1      2    2017       Pune   4/6/2017               Mumbai Indians
# 2      3    2017     Rajkot   4/7/2017                Gujarat Lions
# 3      4    2017     Indore   4/8/2017       Rising Pune Supergiant
# 4      5    2017  Bangalore   4/8/2017  Royal Challengers Bangalore
# ..   ...     ...        ...        ...                          ...
# 631  632    2016     Raipur  5/22/2016             Delhi Daredevils
# 632  633    2016  Bangalore  5/24/2016                Gujarat Lions
# 633  634    2016      Delhi  5/25/2016          Sunrisers Hyderabad
# 634  635    2016      Delhi  5/27/2016                Gujarat Lions
# 635  636    2016  Bangalore  5/29/2016          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               636 non-null    int64
#  1   season           636 non-null    int64
#  2   city             629 non-null    object
#  3   date             636 non-null    object
#  4   team1            636 non-null    object
#  5   team2            636 non-null    object
#  6   toss_winner      636 non-null    object
#  7   toss_decision    636 non-null    object
#  8   result           636 non-null    object
#  9   dl_applied       636 non-null    int64
#  10  winner           633 non-null    object
#  11  win_by_runs      636 non-null    int64
#  12  win_by_wickets   636 non-null    int64
#  13  player_of_match  633 non-null    object
#  14  venue            636 non-null    object
#  15  umpire1          635 non-null    object
#  16  umpire2          635 non-null    object
# ...

# %%
df. describe()
# Out:
#                id       season  dl_applied  win_by_runs  win_by_wickets  \
# count  636.000000   636.000000  636.000000   636.000000      636.000000
# mean   318.500000  2012.490566    0.025157    13.682390        3.372642
# std    183.741666     2.773026    0.156726    23.908877        3.420338
# min      1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%    159.750000  2010.000000    0.000000     0.000000        0.000000
# 50%    318.500000  2012.000000    0.000000     0.000000        4.000000
# 75%    477.250000  2015.000000    0.000000    20.000000        7.000000
# max    636.000000  2017.000000    1.000000   146.000000       10.000000
#
#        umpire3
# count      0.0
# mean       NaN
# std        NaN
# min        NaN
# 25%        NaN
# 50%        NaN
# 75%        NaN
# max        NaN

# %%
df.describe(include = object)
# Out:
#           city      date           team1             team2     toss_winner  \
# count      629       636             636               636             636
# unique      30       450              14                14              14
# top     Mumbai  5/8/2016  Mumbai Indians  Delhi Daredevils  Mumbai Indians
# freq        85         2              82                84              85
#
#        toss_decision  result          winner player_of_match  \
# count            636     636             633             633
# unique             2       3              14             201
# top            field  normal  Mumbai Indians        CH Gayle
# freq             363     626              92              18
#
#                         venue          umpire1     umpire2
# count                     636              635         635
# unique                     35               44          45
# top     M Chinnaswamy Stadium  HDPK Dharmasena  SJA Taufel
# ...

# %%
df.shape
# Out:
# (636, 18)

# %%
df.isnull()
# Out:
#         id  season   city   date  team1  team2  toss_winner  toss_decision  \
# 0    False   False  False  False  False  False        False          False
# 1    False   False  False  False  False  False        False          False
# 2    False   False  False  False  False  False        False          False
# 3    False   False  False  False  False  False        False          False
# 4    False   False  False  False  False  False        False          False
# ..     ...     ...    ...    ...    ...    ...          ...            ...
# 631  False   False  False  False  False  False        False          False
# 632  False   False  False  False  False  False        False          False
# 633  False   False  False  False  False  False        False          False
# 634  False   False  False  False  False  False        False          False
# 635  False   False  False  False  False  False        False          False
#
# ...

# %%
df.isnull().sum()
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               3
# win_by_runs          0
# win_by_wickets       0
# player_of_match      3
# venue                0
# umpire1              1
# umpire2              1
# umpire3            636
# dtype: int64

# %%
df.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
df['city']
# Out:
# 0      Hyderabad
# 1           Pune
# 2         Rajkot
# 3         Indore
# 4      Bangalore
#          ...
# 631       Raipur
# 632    Bangalore
# 633        Delhi
# 634        Delhi
# 635    Bangalore
# Name: city, Length: 636, dtype: object

# %%
df.iloc[0,2]
# Out:
# 'Hyderabad'

# %%
df.sort_values('season', )
# Out:
#     id  season        city       date                   team1  \
# 63  64    2008     Kolkata  4/20/2008         Deccan Chargers
# 60  61    2008  Chandigarh  4/19/2008     Chennai Super Kings
# 61  62    2008       Delhi  4/19/2008        Rajasthan Royals
# 59  60    2008   Bangalore  4/18/2008   Kolkata Knight Riders
# 62  63    2008      Mumbai  4/20/2008          Mumbai Indians
# ..  ..     ...         ...        ...                     ...
# 27  28    2017      Mumbai  4/24/2017  Rising Pune Supergiant
# 28  29    2017        Pune  4/26/2017  Rising Pune Supergiant
# 17  18    2017       Delhi  4/17/2017        Delhi Daredevils
# 16  17    2017   Bangalore  4/16/2017  Rising Pune Supergiant
# 0    1    2017   Hyderabad   4/5/2017     Sunrisers Hyderabad
#
#                           team2                  toss_winner toss_decision  \
# 63        Kolkata Knight Riders              Deccan Chargers           bat
# ...

# %%
df . dropna()
# Out:
# Empty DataFrame
# Columns: [id, season, city, date, team1, team2, toss_winner, toss_decision, result, dl_applied, winner, win_by_runs, win_by_wickets, player_of_match, venue, umpire1, umpire2, umpire3]
# Index: []

# %%
df.head()
# Out:
#    id  season       city      date                        team1  \
# 0   1    2017  Hyderabad  4/5/2017          Sunrisers Hyderabad
# 1   2    2017       Pune  4/6/2017               Mumbai Indians
# 2   3    2017     Rajkot  4/7/2017                Gujarat Lions
# 3   4    2017     Indore  4/8/2017       Rising Pune Supergiant
# 4   5    2017  Bangalore  4/8/2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# 0  normal           0          Sunrisers Hyderabad           35
# ...

# %%
df.shape
# Out:
# (636, 18)

# %%
df.isnull().sum()
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               3
# win_by_runs          0
# win_by_wickets       0
# player_of_match      3
# venue                0
# umpire1              1
# umpire2              1
# umpire3            636
# dtype: int64

# %%
 df.iloc[:,[5,6,10,11 ,12]]
# Out:
#                            team2                  toss_winner  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore
# 1         Rising Pune Supergiant       Rising Pune Supergiant
# 2          Kolkata Knight Riders        Kolkata Knight Riders
# 3                Kings XI Punjab              Kings XI Punjab
# 4               Delhi Daredevils  Royal Challengers Bangalore
# ..                           ...                          ...
# 631  Royal Challengers Bangalore  Royal Challengers Bangalore
# 632  Royal Challengers Bangalore  Royal Challengers Bangalore
# 633        Kolkata Knight Riders        Kolkata Knight Riders
# 634          Sunrisers Hyderabad          Sunrisers Hyderabad
# 635  Royal Challengers Bangalore          Sunrisers Hyderabad
#
#                           winner  win_by_runs  win_by_wickets
# 0            Sunrisers Hyderabad           35               0
# 1         Rising Pune Supergiant            0               7
# ...

# %%
new = df['city']=='Bangalore'
df[new]
# Out:
#       id  season       city       date                        team1  \
# 4      5    2017  Bangalore   4/8/2017  Royal Challengers Bangalore
# 11    12    2017  Bangalore  4/14/2017  Royal Challengers Bangalore
# 16    17    2017  Bangalore  4/16/2017       Rising Pune Supergiant
# 29    30    2017  Bangalore  4/27/2017  Royal Challengers Bangalore
# 41    42    2017  Bangalore   5/5/2017              Kings XI Punjab
# ..   ...     ...        ...        ...                          ...
# 616  617    2016  Bangalore  5/11/2016  Royal Challengers Bangalore
# 619  620    2016  Bangalore  5/14/2016  Royal Challengers Bangalore
# 625  626    2016  Bangalore  5/18/2016  Royal Challengers Bangalore
# 632  633    2016  Bangalore  5/24/2016                Gujarat Lions
# 635  636    2016  Bangalore  5/29/2016          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
new = df['city']=='Bangalore'
df[new].shape[0]
# Out:
# 66

# %%
def get_city_value(city):
    new = df['city']==city
    return df[new]

# %%
get_city_value('Bangalore')
# Out:
#       id  season       city       date                        team1  \
# 4      5    2017  Bangalore   4/8/2017  Royal Challengers Bangalore
# 11    12    2017  Bangalore  4/14/2017  Royal Challengers Bangalore
# 16    17    2017  Bangalore  4/16/2017       Rising Pune Supergiant
# 29    30    2017  Bangalore  4/27/2017  Royal Challengers Bangalore
# 41    42    2017  Bangalore   5/5/2017              Kings XI Punjab
# ..   ...     ...        ...        ...                          ...
# 616  617    2016  Bangalore  5/11/2016  Royal Challengers Bangalore
# 619  620    2016  Bangalore  5/14/2016  Royal Challengers Bangalore
# 625  626    2016  Bangalore  5/18/2016  Royal Challengers Bangalore
# 632  633    2016  Bangalore  5/24/2016                Gujarat Lions
# 635  636    2016  Bangalore  5/29/2016          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
def get_city_data(city):
    new = df['city']==city
    return df[new].shape[0]

# %%
get_city_data('Bangalore')
# Out:
# 66

# %% [markdown]
#  count for win team

# %%
df['winner'].value_counts()
# Out:
# winner
# Mumbai Indians                 92
# Chennai Super Kings            79
# Kolkata Knight Riders          77
# Royal Challengers Bangalore    73
# Kings XI Punjab                70
# Rajasthan Royals               63
# Delhi Daredevils               62
# Sunrisers Hyderabad            42
# Deccan Chargers                29
# Gujarat Lions                  13
# Pune Warriors                  12
# Rising Pune Supergiant         10
# Kochi Tuskers Kerala            6
# Rising Pune Supergiants         5
# Name: count, dtype: int64

# %% [raw]
#  count for win team plot bar with

# %%
df['winner'].value_counts()
# Out:
# winner
# Mumbai Indians                 92
# Chennai Super Kings            79
# Kolkata Knight Riders          77
# Royal Challengers Bangalore    73
# Kings XI Punjab                70
# Rajasthan Royals               63
# Delhi Daredevils               62
# Sunrisers Hyderabad            42
# Deccan Chargers                29
# Gujarat Lions                  13
# Pune Warriors                  12
# Rising Pune Supergiant         10
# Kochi Tuskers Kerala            6
# Rising Pune Supergiants         5
# Name: count, dtype: int64

# %%
df['winner'].value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='winner'>

# %% [markdown]
# count of field or bating with bar

# %%
df['toss_decision'].value_counts()
# Out:
# toss_decision
# field    363
# bat      273
# Name: count, dtype: int64

# %%
df['toss_decision'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
#  toss win chooses   f/b  and count

# %%
df[['toss_winner', 'toss_decision']].value_counts()
# Out:
# toss_winner                  toss_decision
# Royal Challengers Bangalore  field            50
# Kolkata Knight Riders        field            48
# Delhi Daredevils             field            46
# Mumbai Indians               field            45
# Chennai Super Kings          bat              44
# Kings XI Punjab              field            43
# Mumbai Indians               bat              40
# Rajasthan Royals             field            35
# Kolkata Knight Riders        bat              30
# Rajasthan Royals             bat              28
# Delhi Daredevils             bat              26
# Kings XI Punjab              bat              25
# Deccan Chargers              bat              24
# Chennai Super Kings          field            22
# Royal Challengers Bangalore  bat              20
# Deccan Chargers              field            19
# Sunrisers Hyderabad          bat              18
#                              field            17
# ...

# %%
df[['toss_winner', 'toss_decision']].value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='toss_winner,toss_decision'>

# %% [markdown]
# win matches by wickets

# %%
 df['win_by_wickets'].value_counts()
# Out:
# win_by_wickets
# 0     297
# 7      70
# 6      68
# 5      57
# 8      48
# 4      34
# 9      32
# 3      15
# 10     10
# 2       4
# 1       1
# Name: count, dtype: int64

# %%
 df['win_by_wickets'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='win_by_wickets'>

# %% [markdown]
# win match with run count of matchs   left = matches  right = win times

# %%
df['win_by_runs'].value_counts()
# Out:
# win_by_runs
# 0      349
# 10       9
# 7        9
# 9        9
# 23       9
#       ...
# 62       1
# 138      1
# 71       1
# 144      1
# 80       1
# Name: count, Length: 86, dtype: int64

# %%
# whinch teams win year wies maxmim match with count

# %%
in 2008 rr win 13 times

# %%
df[['toss_winner','winner']].value_counts()
# Out:
# season  winner
# 2008    Rajasthan Royals               13
# 2013    Mumbai Indians                 13
# 2012    Kolkata Knight Riders          12
# 2013    Chennai Super Kings            12
# 2014    Kings XI Punjab                12
#                                        ..
# 2009    Kolkata Knight Riders           3
# 2017    Royal Challengers Bangalore     3
# 2015    Kings XI Punjab                 3
# 2008    Deccan Chargers                 2
# 2014    Delhi Daredevils                2
# Name: count, Length: 84, dtype: int64

# %%
df[['season','winner']].value_counts().plot(kind='area')
# Out:
# <Axes: xlabel='season,winner'>

# %% [markdown]
# maxmim match in city

# %%
df['city'].value_counts()
# Out:
# city
# Mumbai            85
# Bangalore         66
# Kolkata           61
# Delhi             60
# Hyderabad         49
# Chennai           48
# Chandigarh        46
# Jaipur            33
# Pune              32
# Durban            15
# Centurion         12
# Ahmedabad         12
# Visakhapatnam     11
# Rajkot            10
# Dharamsala         9
# Johannesburg       8
# Cape Town          7
# Port Elizabeth     7
# Ranchi             7
# Abu Dhabi          7
# Cuttack            7
# Raipur             6
# Sharjah            6
# Indore             5
# Kochi              5
# Kanpur             4
# East London        3
# Kimberley          3
# Nagpur             3
# Bloemfontein       2
# Name: count, dtype: int64

# %%
df['city'].value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='city'>

# %% [markdown]
#  win toss with win match count

# %%
df[['toss_winner','winner']].value_counts()
# Out:
# toss_winner                  winner
# Mumbai Indians               Mumbai Indians                 48
# Kolkata Knight Riders        Kolkata Knight Riders          44
# Chennai Super Kings          Chennai Super Kings            42
# Royal Challengers Bangalore  Royal Challengers Bangalore    35
# Rajasthan Royals             Rajasthan Royals               34
#                                                             ..
# Rising Pune Supergiants      Kolkata Knight Riders           1
# Rajasthan Royals             Pune Warriors                   1
# Royal Challengers Bangalore  Gujarat Lions                   1
# Sunrisers Hyderabad          Kings XI Punjab                 1
#                              Rising Pune Supergiant          1
# Name: count, Length: 114, dtype: int64

# %%
ax = df[['toss_winner','winner']].value_counts().head(20).plot(kind='barh')
plt.figure(figsize=(2,100))

# %% [markdown]
# max count of player_of_match

# %%
df['player_of_match'].value_counts()
# Out:
# player_of_match
# CH Gayle             18
# YK Pathan            16
# DA Warner            15
# AB de Villiers       15
# RG Sharma            14
#                      ..
# SA Yadav              1
# Mustafizur Rahman     1
# CR Brathwaite         1
# A Zampa               1
# BCJ Cutting           1
# Name: count, Length: 201, dtype: int64

# %%
df['player_of_match'].value_counts().head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='player_of_match'>

# %%
df['player_of_match'].value_counts().head(30).plot(kind='pie')
# Out:
# <Axes: ylabel='count'>
